# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/프로젝트오리엔테이션/titanic.csv')

# %%
df.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.corr()
# Out:
#             pclass  survived       age     sibsp     parch      fare      body
# pclass    1.000000 -0.312469 -0.408106  0.060832  0.018322 -0.558629 -0.034642
# survived -0.312469  1.000000 -0.055512 -0.027825  0.082660  0.244265       NaN
# age      -0.408106 -0.055512  1.000000 -0.243699 -0.150917  0.178740  0.058809
# sibsp     0.060832 -0.027825 -0.243699  1.000000  0.373587  0.160238 -0.099961
# parch     0.018322  0.082660 -0.150917  0.373587  1.000000  0.221539  0.051099
# fare     -0.558629  0.244265  0.178740  0.160238  0.221539  1.000000 -0.043110
# body     -0.034642       NaN  0.058809 -0.099961  0.051099 -0.043110  1.000000

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.describe(include=['O'])
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1307  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      914   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
df[['pclass', 'survived']].groupby(['pclass'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#    pclass  survived
# 0       1  0.619195
# 1       2  0.429603
# 2       3  0.255289

# %%
sns.countplot(x="pclass", hue="survived", data=df)
plt.show()

# %% [markdown]
# ### class별 생존률
# - 높은 class의 사람들이 생존률이 높다.
# -- 특히 3class의 사람들의 사망률은 매우 높다.

# %%
df[['sex', 'survived']].groupby(['sex'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#       sex  survived
# 0  female  0.727468
# 1    male  0.190985

# %%
sns.countplot(x="sex", hue="survived", data=df)
plt.show()

# %% [markdown]
# ### 성별 생존률
# - 남성의 사망률은 매우 높은 반면
# - 여성의 생존률은 매우 높다

# %%
df[['sibsp', 'survived']].groupby(['sibsp'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#    sibsp  survived
# 1      1  0.510972
# 2      2  0.452381
# 0      0  0.346801
# 3      3  0.300000
# 4      4  0.136364
# 5      5  0.000000
# 6      8  0.000000

# %%
sns.countplot(y="sibsp", hue="survived", data=df)
plt.show()

# %% [markdown]
# ### 형제가 있는 사람들의 생존률
# - 형제가 3명 이상인 사람들은 형제가 없는 사람들보다 생존률이 낮다.

# %%
df[['parch', 'survived']].groupby(['parch'], as_index=False).mean().sort_values(by='survived', ascending=False)
# Out:
#    parch  survived
# 3      3  0.625000
# 1      1  0.588235
# 2      2  0.504425
# 0      0  0.335329
# 4      4  0.166667
# 5      5  0.166667
# 6      6  0.000000
# 7      9  0.000000

# %%
sns.countplot(y="parch", hue="survived", data=df)
plt.show()

# %% [markdown]
# ### 부모와 동반한 사람들의 생존률
# - 부모와 동반한 사람들의 경우 동행인이 3인 이하인 경우 생존률이 높다.

# %%
pd.set_option('display.max_rows', 30)
df['cabin'].to_frame()
# Out:
#         cabin
# 0          B5
# 1     C22 C26
# 2     C22 C26
# 3     C22 C26
# 4     C22 C26
# ...       ...
# 1304        T
# 1305        T
# 1306        T
# 1307        T
# 1308        T
#
# [1309 rows x 1 columns]

# %%
df.loc[df['cabin']!=df['cabin'],'cabin'] = '-'
df.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
df.replace('F E69','E',inplace=True)

# %%
result[5] #Before
# Out:
#       pclass  survived                                              name  \
# 339        2         1                         Becker, Master. Richard F
# 340        2         1                       Becker, Miss. Marion Louise
# 341        2         1                      Becker, Miss. Ruth Elizabeth
# 342        2         1  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 349        2         1                     Brown, Miss. Amelia "Mildred"
# 380        2         1                        Cook, Mrs. (Selena Rogers)
# 484        2         1                      Lemore, Mrs. (Amelia Milley)
# 514        2         1                    Navratil, Master. Edmond Roger
# 515        2         1                        Navratil, Master. Michel M
# 516        2         0          Navratil, Mr. Michel ("Louis M Hoffman")
# 517        2         0                                Nesson, Mr. Israel
# 521        2         1                      Nye, Mrs. (Elizabeth Ramell)
# ...

# %%
df.replace('X Y00','Y',inplace=True) # 가령 X Y00이라는 문자가 있다면 Y값으로 변경하였다.

# %%
result[5] #After
# Out:
#       pclass  survived                                              name  \
# 339        2         1                         Becker, Master. Richard F
# 340        2         1                       Becker, Miss. Marion Louise
# 341        2         1                      Becker, Miss. Ruth Elizabeth
# 342        2         1  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 349        2         1                     Brown, Miss. Amelia "Mildred"
# 380        2         1                        Cook, Mrs. (Selena Rogers)
# 484        2         1                      Lemore, Mrs. (Amelia Milley)
# 514        2         1                    Navratil, Master. Edmond Roger
# 515        2         1                        Navratil, Master. Michel M
# 516        2         0          Navratil, Mr. Michel ("Louis M Hoffman")
# 517        2         0                                Nesson, Mr. Israel
# 521        2         1                      Nye, Mrs. (Elizabeth Ramell)
# ...

# %%
a = ['A','B','C','D','E','F','G']
result = []
for i in range(7) :
    result.append(df[df['cabin'].str.contains(a[i])])

# %%
Tresult = pd.concat([result[0],result[1],result[2],result[3],result[4],result[5],result[6]])

# %%
Tresult['survived'].hist()

# %%
names = ['1','0']
dl = [Tresult[Tresult['survived'] == 1]['cabin'].count(),Tresult[Tresult['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=Tresult)
plt.show()

# %%
dl = []
for i in range (7):
    dl.append((result[i][result[i]['survived'] == 1]['cabin'].count() + result[i][result[i]['survived'] == 0]['cabin'].count()).mean())

# %%
names = ['A','B','C','D','E','F','G']
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show(); # 각 cabin별 생존률

# %%
result[0]['survived'].hist() #cabin(A)

# %%
names = ['1','0']
dl = [result[0][result[0]['survived'] == 1]['cabin'].count(),result[0][result[0]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[0])
plt.show()

# %%
result[1]['survived'].hist() #cabin(B)

# %%
names = ['1','0']
dl = [result[1][result[1]['survived'] == 1]['cabin'].count(),result[1][result[1]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[1])
plt.show()

# %%
result[2]['survived'].hist() #cabin(C)

# %%
names = ['1','0']
dl = [result[2][result[2]['survived'] == 1]['cabin'].count(),result[2][result[2]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[2])
plt.show()

# %%
result[3]['survived'].hist() #cabin(D)

# %%
names = ['1','0']
dl = [result[3][result[3]['survived'] == 1]['cabin'].count(),result[3][result[3]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[3])
plt.show()

# %%
result[4]['survived'].hist() #cabin(E)

# %%
names = ['1','0']
dl = [result[4][result[4]['survived'] == 1]['cabin'].count(),result[4][result[4]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[4])
plt.show()

# %%
result[5]['survived'].hist() #cabin(F)

# %%
names = ['1','0']
dl = [result[5][result[5]['survived'] == 1]['cabin'].count(),result[5][result[5]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[5])
plt.show()

# %%
result[6]['survived'].hist() #cabin(G)

# %%
names = ['1','0']
dl = [result[6][result[6]['survived'] == 1]['cabin'].count(),result[6][result[6]['survived'] == 0]['cabin'].count()]
plt.pie(dl, labels=names, labeldistance=1.15);
plt.show();

# %%
sns.countplot(x="sex", hue="survived", data=result[6])
plt.show()

# %% [markdown]
# ### cabin정보가 있는 사람들의 생존률과 성비율
# - cabin정보가 있는 사람들의 생존률은 65%정도로 추정된다
# - A,G cabin을 제외한 cabin의 생존률은 사망률보다 높다
# - cabin 정보가 있는 사람들의 생존률도 여성이 남성보다 월등히 높다

# %%
df.loc[df['boat']!=df['boat'],'boat'] = 0

# %%
df['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
df[df['survived'] == 1]['boat'].count()
# Out:
# 500

# %%
df[df['boat'] == 0]['survived'].sum()
# Out:
# 23

# %%
s = df[df['boat'] == 0][df['survived'] == 1]
s
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       pclass  survived                                               name  \
# 192        1         1                               Lurette, Miss. Elise
# 358        2         1                           Bystrom, Mrs. (Karolina)
# 395        2         1                                Doling, Miss. Elsie
# 396        2         1               Doling, Mrs. John T (Ada Julia Bone)
# 458        2         1                                Ilett, Miss. Bertha
# 489        2         1  Louch, Mrs. Charles Alexander (Alice Adelaide ...
# 513        2         1                Nasser, Mrs. Nicholas (Adele Achem)
# 545        2         1        Renouf, Mrs. Peter Henry (Lillian Jefferys)
# 572        2         1                   Trout, Mrs. William H (Jessie L)
# ...

# %%
sns.countplot(x="sex", hue="survived", data=s)
plt.show()

# %% [markdown]
# ### 생존자 중 보트를 타지않은 것으로 추정되는 사람들의 성비율
# - 보트를 타지 않고 생존한 것으로 추정되는 사람중 21명은 여성이다.
# - 남성의 경우 2명만이 보트를 타지 않고 살아남은 것으로 추정된다.
